# %%
import numpy as np # type: ignore
import plotly.express as px # type: ignore
import plotly.graph_objects as go # type: ignore
import matplotlib.pyplot as plt # type: ignore

# %%
a = np.linspace(-10, 9, 20)
b = np.linspace(-10, 9, 20)

# %%
# mesh-grid --> draw point of every possible way

xx, yy = np.meshgrid(a, b)

# %%
plt.scatter(xx, yy)

# %%
def func(x, y):
    return (x ** 2) + (y ** 2)

zz = func(xx, yy)
zz
# Out:
# array([[200., 181., 164., 149., 136., 125., 116., 109., 104., 101., 100.,
#         101., 104., 109., 116., 125., 136., 149., 164., 181.],
#        [181., 162., 145., 130., 117., 106.,  97.,  90.,  85.,  82.,  81.,
#          82.,  85.,  90.,  97., 106., 117., 130., 145., 162.],
#        [164., 145., 128., 113., 100.,  89.,  80.,  73.,  68.,  65.,  64.,
#          65.,  68.,  73.,  80.,  89., 100., 113., 128., 145.],
#        [149., 130., 113.,  98.,  85.,  74.,  65.,  58.,  53.,  50.,  49.,
#          50.,  53.,  58.,  65.,  74.,  85.,  98., 113., 130.],
#        [136., 117., 100.,  85.,  72.,  61.,  52.,  45.,  40.,  37.,  36.,
#          37.,  40.,  45.,  52.,  61.,  72.,  85., 100., 117.],
#        [125., 106.,  89.,  74.,  61.,  50.,  41.,  34.,  29.,  26.,  25.,
#          26.,  29.,  34.,  41.,  50.,  61.,  74.,  89., 106.],
#        [116.,  97.,  80.,  65.,  52.,  41.,  32.,  25.,  20.,  17.,  16.,
#          17.,  20.,  25.,  32.,  41.,  52.,  65.,  80.,  97.],
# ...

# %%
fig = px.scatter_3d()
fig.add_trace(go.Surface(x = xx, y = yy, z = zz))
fig.show()

# %%
# working with random

np.random.random((2, 3, 2))
# Out:
# array([[[0.46898577, 0.35991901],
#         [0.07835138, 0.2887955 ],
#         [0.39716102, 0.81049691]],
#
#        [[0.51434528, 0.8923824 ],
#         [0.56424059, 0.91859433],
#         [0.31006899, 0.29141773]]])

# %%
np.random.randint(1, 100, 10).reshape(2, 5)
# Out:
# array([[96, 19, 25, 26, 10],
#        [ 7, 78, 36, 31, 21]], dtype=int32)

# %%
# seed() -> always print same random value
np.random.seed(0)
np.random.randint(1, 100, 12).reshape(3, 4)
# Out:
# array([[45, 48, 65, 68],
#        [68, 10, 84, 22],
#        [37, 88, 71, 89]], dtype=int32)

# %%
np.random.seed(0)
np.random.randint(1, 100, 12).reshape(3, 4)
# Out:
# array([[45, 48, 65, 68],
#        [68, 10, 84, 22],
#        [37, 88, 71, 89]], dtype=int32)

# %%
# shuffle

a = np.array([9, 1, 2, 5, 8, 3, 6])
np.random.shuffle(a)

# %%
a
# Out:
# array([6, 5, 3, 1, 2, 8, 9])

# %%
# choice -> randomly pick item

np.random.choice(a, 3) # with replacement value can repeat
np.random.choice(a, 3, replace=False) # without replacement value can not repeat
# Out:
# array([3, 1, 2])

# %%
# working with image

import cv2 # type: ignore

# %%
img = cv2.imread("./photo.png") # give me numpy array and it read bgr not rgb hence it show different color

# %%
img.shape
# Out:
# (1728, 1300, 3)

# %%
plt.imshow(img)
plt.imshow(np.flip(img, axis = 1))
plt.imshow(np.flip(img))

# %%
# flip 

a = np.arange(6).reshape(2, 3)
np.flip(a)
# Out:
# array([[5, 4, 3],
#        [2, 1, 0]])

# %%
# clip -> take value in range

np.clip(a, 2, 3)
# Out:
# array([[2, 2, 2],
#        [3, 3, 3]])

# %%
img.max() # all value are from 0 - 255
plt.imshow(np.clip(img, 0, 100))

# %%
# negative

plt.imshow(255 - img)

# %%
# trim 

plt.imshow(img[100:500, 100:500, :])
plt.imshow(img[100:500, 50:900, :])

# %%
# plot histogram
plt.hist(img.flatten(), bins = 255)
# Out:
# (array([4.00000e+00, 0.00000e+00, 1.00000e+00, 4.00000e+00, 3.00000e+00,
#         2.00000e+00, 1.00000e+00, 5.00000e+00, 1.00000e+00, 8.00000e+00,
#         3.00000e+00, 1.00000e+01, 5.00000e+00, 2.00000e+00, 6.00000e+00,
#         4.00000e+00, 1.20000e+01, 1.50000e+01, 1.90000e+01, 1.50000e+01,
#         1.80000e+01, 1.60000e+01, 2.60000e+01, 2.90000e+01, 2.30000e+01,
#         4.20000e+01, 3.00000e+01, 3.70000e+01, 4.00000e+01, 4.80000e+01,
#         5.40000e+01, 6.90000e+01, 7.10000e+01, 8.60000e+01, 1.29000e+02,
#         1.38000e+02, 1.28000e+02, 2.02000e+02, 2.69000e+02, 3.62000e+02,
#         6.28000e+02, 1.01500e+03, 1.65800e+03, 2.62700e+03, 3.55600e+03,
#         4.79800e+03, 6.62900e+03, 9.82300e+03, 1.43820e+04, 1.83030e+04,
#         2.37810e+04, 3.49210e+04, 4.80010e+04, 5.72070e+04, 6.33380e+04,
#         7.51880e+04, 1.00946e+05, 1.38769e+05, 1.57859e+05, 1.60586e+05,
#         1.25083e+05, 1.05634e+05, 9.64290e+04, 8.00600e+04, 7.55160e+04,
# ...

# %%
# structured array -> create heterogenous array
np.array([1, 2, 3, 4, 5])
a = np.array([1, True, 'Hello', 3.5]) # everything is string

# %%
# a[0] / 100 # not possible

# %%
dt = np.dtype([
    ('name', 'U20'),
    ('iq', np.int32),
    ('cgpa', np.float64),
    ('placed', 'U20')
])

# %%
dt
# Out:
# dtype([('name', '<U20'), ('iq', '<i4'), ('cgpa', '<f8'), ('placed', '<U20')])

# %%
stu = np.array(
    [
        ('pappu', 70, 3.4, 'Yes'),
        ('tappu', 90, 3.9, 'No')
    ], dtype=dt
)

# %%
stu[0][0]
stu[0][1]
stu['name']
stu['iq']
stu['placed']
# Out:
# array(['Yes', 'No'], dtype='<U20')

# %%
np.save("student.npy", stu)

# %%
b = np.load("./student.npy")
b
# Out:
# array([('pappu', 70, 3.4, 'Yes'), ('tappu', 90, 3.9, 'No')],
#       dtype=[('name', '<U20'), ('iq', '<i4'), ('cgpa', '<f8'), ('placed', '<U20')])
